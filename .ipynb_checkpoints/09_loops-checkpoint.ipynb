# %%
list=["apple","banana","mango"]

# %%
for i in list:
    print(i)

# %%
i =0

while(i <5):
    if(i==3):
        break
    print(i)
    i=i+1

# %%
i =0
while(i<5):
    if(i==3):
        continue
    print(i)
    i=i+1
