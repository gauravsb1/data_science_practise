# %%
 a=5

# %%
b=6

# %%
a+b
# Out:
# 11

# %%
name="gaurav"

# %%
print("hi") #this will print hi
# Out:
# hi

# %%
# this is comment

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
print(type(name))
# Out:
# <class 'str'>

# %%
type(name)
# Out:
# str

# %%
a="123"

# %%
b="432"

# %%
print(a+b)
# Out:
# 123432

# %%
int(a)+int(b) #typecast
# Out:
# 555
