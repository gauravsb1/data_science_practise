# %%
name="gaurav"

# %%
name
# Out:
# 'gaurav'

# %%
name.upper()
# Out:
# 'GAURAV'

# %%
name.endswith("av")
# Out:
# True

# %%
name.endswith("rv")
# Out:
# False

# %%
name.lower()
# Out:
# 'gaurav'

# %%
name.count("v")
# Out:
# 1

# %%
name.count("a")
# Out:
# 2

# %%
len(name)
# Out:
# 6

# %%
name[0:3]
# Out:
# 'gau'

# %%
name[0:-1]
# Out:
# 'gaura'

# %%
name[0:5]
# Out:
# 'gaura'

# %%
name[-5:-1]
# Out:
# 'aura'

# %%
name[1:5]
# Out:
# 'aura'
