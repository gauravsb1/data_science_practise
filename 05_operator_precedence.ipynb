# %%
12+1*4
# Out:
# 16

# %%
(12+1*4)
# Out:
# 16

# %%
2**2+1
# Out:
# 5

# %%
2/2*3
# Out:
# 3.0

# %%
2//2*3
# Out:
# 3

# %%
(2+1)*2//2+2**2
# Out:
# 7

# %%
2+1**2%2+(2+1)-2
# Out:
# 4

# %%
2+1**2**2%2+(2+1)-2
# Out:
# 4
