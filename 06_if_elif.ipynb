# %%
a=400

# %%
if(a>45):
    print("greater")
else:
    print("samller")
# Out:
# greater

# %%
age=18

# %%
if(age<18):
    print("cant drive")

elif(age==18):
    print("give test")

else:
    print("can drive")
# Out:
# give test

# %%
#function

# %%
def add(a,b):
    return a+b

# %%
add(2,3)
# Out:
# 5

# %%
def add():
    print("hi")

# %%
add()
# Out:
# hi

# %%
def add(a,b,c=2):
    return(a+b+c)

# %%
add(2,2,1) #it will consider this argument
# Out:
# 5

# %%
add(2,2) #now it will consider default value of c=2
# Out:
# 6
