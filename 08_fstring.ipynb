# %%
name="gaurav"
age=15

# %%
print(f"my name is {name} ,i am {age} years old")
# Out:
# my name is gaurav ,i am 15old

# %%
#string padding

# %%
print(f"{'python' :<10}")
print(f"{'python' :>10}")
print(f"{'python' :^10}")
# Out:
# python
#     python
#   python

# %%
print(f"{'name':<10}{'marks':>10}")

print(f"{'gaurav':<10}{58:>10}")

print(f"{'aman':<10}{45:>10}")
# Out:
# name           marks
# gaurav            58
# aman              45
