# %%
l=[1,2,5,6]

# %%
l[0]=100

# %%
l
# Out:
# [100, 2, 5, 6]

# %%
l.append(200)

# %%
l
# Out:
# [100, 2, 5, 6, 200]

# %%
l2=[0,1]

# %%
l.extend(l2)

# %%
l
# Out:
# [100, 2, 5, 6, 200, 0, 1]

# %%
l.insert(1,11)

# %%
l
# Out:
# [100, 11, 2, 5, 6, 200, 0, 1]

# %%
l.pop(5)
# Out:
# 200

# %%
l
# Out:
# [100, 11, 2, 5, 6, 0, 1]

# %%
l.index(11)
# Out:
# 1

# %%
l.append(2)

# %%
l
# Out:
# [100, 11, 2, 5, 6, 0, 1, 2]

# %%
l.count(2)
# Out:
# 2

# %%
l.sort()  #original list will be sort

# %%
l
# Out:
# [0, 1, 2, 2, 5, 6, 11, 100]

# %%
newl=[2,200,1,5]

# %%
sorted(newl) #new list will be sorted
# Out:
# [1, 2, 5, 200]

# %%
newl
# Out:
# [2, 200, 1, 5]

# %%
y=[1,True,False,[2,3]]

# %%
y
# Out:
# [1, True, False, [2, 3]]

# %%
y[3]
# Out:
# [2, 3]

# %%
y[3][1]
# Out:
# 3

# %%
l1=[1,2,3]

# %%
l2=[4,5,6]

# %%
l1+l2
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
l1
# Out:
# [1, 2, 3]

# %%
if 3 in l1:
    print("true")
# Out:
# true

# %%
4 in l1
# Out:
# False

# %%
s="gv-rv-sv-tv"

# %%
s.split("-")
# Out:
# ['gv', 'rv', 'sv', 'tv']
