# %%
e=()

# %%
e
# Out:
# ()

# %%
type(e)
# Out:
# tuple

# %%
t=(1,2,3,4)

# %%
t
# Out:
# (1, 2, 3, 4)

# %%
t[1] #acess element same as lsit
# Out:
# 2

# %%
len(t)
# Out:
# 4

# %%
#packing
person=('gaurav',22,'india')

# %%
#unpacking

name,age,country=person

# %%
age
# Out:
# 22

# %%
country
# Out:
# 'india'
