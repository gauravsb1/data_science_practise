# %%
a={}

# %%
type(a)
# Out:
# dict

# %%
b=set() #empty set

# %%
type(b)
# Out:
# set

# %%
s={2,4,5,1,2}

# %%
s
# Out:
# {1, 2, 4, 5}

# %%
s.add(5)

# %%
s
# Out:
# {1, 2, 4, 5}

# %%
s.add(35)

# %%
s
# Out:
# {1, 2, 4, 5, 35}

# %%
s.update([36,37])

# %%
s
# Out:
# {1, 2, 4, 5, 35, 36, 37}

# %%
s.remove(2)

# %%
s
# Out:
# {1, 4, 5, 35, 36, 37}

# %%
s.discard(2)

# %%
s
# Out:
# {1, 4, 5, 35, 36, 37}

# %%
s.pop()
# Out:
# 1

# %%
s.pop()
# Out:
# 35

# %%
set1={1,2,3,4}

# %%
set2={1,4,5,6}

# %%
set1.union(set2)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
set1.intersection(set2)
# Out:
# {1, 4}

# %%
sub={1,2}

# %%
sub.issubset(set1)
# Out:
# True

# %%
set1.issuperset(sub)
# Out:
# True
