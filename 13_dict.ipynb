# %%
d={}

# %%
type(d)
# Out:
# dict

# %%
d={
    "name":"gaurav",
    "age":23,
    "city":"ddun"
}

# %%
print(d["name"])
# Out:
# gaurav

# %%
d["name"]="rahul"

# %%
print(d)
# Out:
# {'name': 'rahul', 'age': 23, 'city': 'ddun'}

# %%
d.keys()
# Out:
# dict_keys(['name', 'age', 'city'])

# %%
d.values()
# Out:
# dict_values(['rahul', 23, 'ddun'])

# %%
d.items()
# Out:
# dict_items([('name', 'rahul'), ('age', 23), ('city', 'ddun')])

# %%
d.update({"name":"gv"})

# %%
print(d)
# Out:
# {'name': 'gv', 'age': 23, 'city': 'ddun'}

# %%
d.update({"language":"hindi"})

# %%
d
# Out:
# {'name': 'gv', 'age': 23, 'city': 'ddun', 'language': 'hindi'}

# %%
 d.pop("language")
# Out:
# 'hindi'

# %%
print(d)
# Out:
# {'name': 'gv', 'age': 23, 'city': 'ddun'}
