# %%
import pandas as pd

# %%
df=pd.read_excel("Eligible Students List.xlsx")

# %%
df
# Out:
#        SNo         Student Name Enrollment Number University Name  Course  \
# 0        1        Aabhash Anand       PV-23180100   GEHU-Dehradun  B-Tech
# 1        2     Aaditya Bhardwaj       PV-23180101   GEHU-Dehradun  B-Tech
# 2        3         Aaditya Paul      GE-232024211             GEU  B-Tech
# 3        4  Aaditya Singh Rawat      GE-232023161             GEU  B-Tech
# 4        5    Aaditya Sundriyal       PV-23610011    GEHU-Bhimtal  B-Tech
# ...    ...                  ...               ...             ...     ...
# 5698  5699     ROHIT SINGH NEGI      GE-242026231             GEU  B-Tech
# 5699  5700         VANSH SHARMA      GE-242026249             GEU  B-Tech
# 5700  5701         AASTIK GUPTA      GE-242026301             GEU  B-Tech
# 5701  5702        NISHANT SINGH      GE-242026334             GEU  B-Tech
# 5702  5703         AADI CHAMOLI      GE-242026402             GEU  B-Tech
#
#                               Branch       Personal E-mail Address  \
# ...

# %%
df.head()
# Out:
#    SNo         Student Name Enrollment Number University Name  Course  \
# 0    1        Aabhash Anand       PV-23180100   GEHU-Dehradun  B-Tech
# 1    2     Aaditya Bhardwaj       PV-23180101   GEHU-Dehradun  B-Tech
# 2    3         Aaditya Paul      GE-232024211             GEU  B-Tech
# 3    4  Aaditya Singh Rawat      GE-232023161             GEU  B-Tech
# 4    5    Aaditya Sundriyal       PV-23610011    GEHU-Bhimtal  B-Tech
#
#                            Branch       Personal E-mail Address  \
# 0  Computer Science & Engineering        abhasanand07@gmail.com
# 1  Computer Science & Engineering  bhardwajaaditiya19@gmail.com
# 2  Computer Science & Engineering           aadibpaul@gmail.com
# 3  Computer Science & Engineering  armansinghrawat508@gmail.com
# 4  Computer Science & Engineering   aadityaasundriyal@gmail.com
#
#    Mobile Number  Passing out Batch
# 0     9418351209               2027
# 1     7454014515               2027
# 2     9317000929               2027
# ...

# %%
df.tail()
# Out:
#        SNo      Student Name Enrollment Number University Name  Course  \
# 5698  5699  ROHIT SINGH NEGI      GE-242026231             GEU  B-Tech
# 5699  5700      VANSH SHARMA      GE-242026249             GEU  B-Tech
# 5700  5701      AASTIK GUPTA      GE-242026301             GEU  B-Tech
# 5701  5702     NISHANT SINGH      GE-242026334             GEU  B-Tech
# 5702  5703      AADI CHAMOLI      GE-242026402             GEU  B-Tech
#
#                               Branch     Personal E-mail Address  \
# 5698  Computer Science & Engineering     ROHITNEGI1009@GMAIL.COM
# 5699  Computer Science & Engineering        VS00019368@GMAIL.COM
# 5700  Computer Science & Engineering        aastik2006@gmail.com
# 5701  Computer Science & Engineering  SINGHNISHANT0131@GMAIL.COM
# 5702  Computer Science & Engineering     AADICHAMOLI06@GMAIL.COM
#
#       Mobile Number  Passing out Batch
# 5698     7078275409               2028
# 5699     9368841540               2028
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of        SNo         Student Name Enrollment Number University Name  Course  \
# 0        1        Aabhash Anand       PV-23180100   GEHU-Dehradun  B-Tech
# 1        2     Aaditya Bhardwaj       PV-23180101   GEHU-Dehradun  B-Tech
# 2        3         Aaditya Paul      GE-232024211             GEU  B-Tech
# 3        4  Aaditya Singh Rawat      GE-232023161             GEU  B-Tech
# 4        5    Aaditya Sundriyal       PV-23610011    GEHU-Bhimtal  B-Tech
# ...    ...                  ...               ...             ...     ...
# 5698  5699     ROHIT SINGH NEGI      GE-242026231             GEU  B-Tech
# 5699  5700         VANSH SHARMA      GE-242026249             GEU  B-Tech
# 5700  5701         AASTIK GUPTA      GE-242026301             GEU  B-Tech
# 5701  5702        NISHANT SINGH      GE-242026334             GEU  B-Tech
# 5702  5703         AADI CHAMOLI      GE-242026402             GEU  B-Tech
#
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of        SNo         Student Name Enrollment Number University Name  Course  \
# 0        1        Aabhash Anand       PV-23180100   GEHU-Dehradun  B-Tech
# 1        2     Aaditya Bhardwaj       PV-23180101   GEHU-Dehradun  B-Tech
# 2        3         Aaditya Paul      GE-232024211             GEU  B-Tech
# 3        4  Aaditya Singh Rawat      GE-232023161             GEU  B-Tech
# 4        5    Aaditya Sundriyal       PV-23610011    GEHU-Bhimtal  B-Tech
# ...    ...                  ...               ...             ...     ...
# 5698  5699     ROHIT SINGH NEGI      GE-242026231             GEU  B-Tech
# 5699  5700         VANSH SHARMA      GE-242026249             GEU  B-Tech
# 5700  5701         AASTIK GUPTA      GE-242026301             GEU  B-Tech
# 5701  5702        NISHANT SINGH      GE-242026334             GEU  B-Tech
# 5702  5703         AADI CHAMOLI      GE-242026402             GEU  B-Tech
#
# ...

# %%
import matplotlib.pyplot as plt

# %%
labels=['GEHU-Bhimtal' ,'GEHU-Dehradun','GEHU-Haldwani ','GEU']

colors=['red','yellow','blue' ,'orange' ]

# %%
count=df.groupby('University Name').size()

# %%
count
# Out:
# University Name
# GEHU-Bhimtal      855
# GEHU-Dehradun    2759
# GEHU-Haldwani     163
# GEU              1926
# dtype: int64

# %%
plt.pie(count, colors=colors, labels=labels, autopct='%1.1f%%',explode = [0, 0.1, 0, 0] ,
        wedgeprops={'edgecolor': 'black', 'linewidth': 2, 'linestyle': '--'}
       
       )

plt.show()

# %%
df[df['Mobile Number'].astype(str).str.endswith('938')]
# Out:
#        SNo        Student Name Enrollment Number University Name  Course  \
# 582    583          Arpit Negi       PV-23180495   GEHU-Dehradun  B-Tech
# 1041  1042  Gaurav Singh Bisht       PV-23180802   GEHU-Dehradun  B-Tech
#
#                               Branch     Personal E-mail Address  \
# 582   Computer Science & Engineering     negiarpit2005@gmail.com
# 1041  Computer Science & Engineering  gaurav12345bisht@gmail.com
#
#       Mobile Number  Passing out Batch
# 582      8979579938               2027
# 1041     9389135938               2027
