# %%
import json

#function to load the json data

def load_data(filename):
    with open(filename,"r") as f:
        return json.load(f)

# fun to find pages user might like based on commnon interest
def find_pages_u_might_like(user_id,data):
    #dictinory to store user interaction with pages
    user_pages={}

    for user in data['user']:
        user_pages[user['id']]= set(user['liked_pages'])

    #if user not found return empty list
    if user not in user_pages:
        return []

    user_liked_pages=user_pages[user_id]
# Out:
#   Cell In[4], line 15
#
#     ^
# _IncompleteInputError: incomplete input
