# %%
from sklearn.tree  import  DecisionTreeClassifier

# %%
features=[  [150, 0],  # Apple
          
            [170, 0],  # Apple
          
            [130, 1],  # Orange
          
            [120, 1],  # Orange



]

# %%
labels=["apples" ,"apples","orange" ,"orange"]

# %%
clf=DecisionTreeClassifier()

# %%
clf=clf.fit(features, labels)

# %%
prediction=clf.predict([[180,0] ,[20,1]])

# %%
for i in range ( 0,2):

   print(f"this fruit is {prediction[i]}" )
# Out:
# this fruit is apples
# this fruit is orange

# %%
##visualization

# %%
from sklearn.tree import plot_tree

import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(11,11))

# %%
plot_tree(clf,feature_names=["weight","color"],class_names=["apple","orange"],filled=True)

plt.show()
