# %%
import numpy as np

# %%
arr=np.array([1,2,3,4])

result=arr**2                #vectorization

# %%
result
# Out:
# array([ 1,  4,  9, 16])

# %%
result+10                    #broadcast
# Out:
# array([11, 14, 19, 26])

# %%
arr1=np.array([[1,2,3],
               [4,5,6]
              ])

arr2=np.array([1,2,3])


res=arr1+arr2     #broadcast arr2 across arr1

# %%
res
# Out:
# array([[2, 4, 6],
#        [5, 7, 9]])
