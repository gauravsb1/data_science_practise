# %%
import numpy as np

# %%
arr=np.array([1,2,3])

# %%
arr.dtype
# Out:
# dtype('int64')

# %%
arr.astype("float64")
# Out:
# array([1., 2., 3.])

# %%
arr2=np.array([1,2,3], dtype="float32")

# %%
arr2
# Out:
# array([1., 2., 3.], dtype=float32)

# %%
arr2.nbytes
# Out:
# 12

# %%
arr.nbytes
# Out:
# 24
