# %%
import pandas as pd

# %%
s1=pd.Series([22,33,44,55])

# %%
type(s1)
# Out:
# pandas.core.series.Series

# %%
print(s1)
# Out:
# 0    22
# 1    33
# 2    44
# 3    55
# dtype: int64

# %%
s2=pd.Series([22,33,44,55] ,index=["ravi","mohit","aman","ram"])

# %%
print(s2)
# Out:
# ravi     22
# mohit    33
# aman     44
# ram      55
# dtype: int64

# %%
s2["ravi"]
# Out:
# np.int64(22)

# %%
s2["aman"]
# Out:
# np.int64(44)

# %%
data = {
    "name": ["Alice", "Bob", "Charlie"],
    "age": [25, 30, 35],
    "city": ["Delhi", "Mumbai", "Bangalore"]
}

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#       name  age       city
# 0    Alice   25      Delhi
# 1      Bob   30     Mumbai
# 2  Charlie   35  Bangalore

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df.columns
# Out:
# Index(['name', 'age', 'city'], dtype='object')
